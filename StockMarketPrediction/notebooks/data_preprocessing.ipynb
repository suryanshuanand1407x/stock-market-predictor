# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('/Users/suryanshu/Downloads/SPBSS5IP_01122020_25122024.csv', parse_dates=['Date'])

# Check for missing values
print(data.isnull().sum())

# Handle missing values if any
data.fillna(method='ffill', inplace=True)

# Set date as index
data.set_index('Date', inplace=True)

# Plot the closing price trend
plt.figure(figsize=(12, 6))
plt.plot(data['Close'], label='Close Price')
plt.title('Closing Price Trend')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64
# /var/folders/h7/7m31mxnj50s64_l3_sjbqjyh0000gn/T/ipykernel_87995/1373883973.py:11: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
